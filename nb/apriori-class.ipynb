# %%
from typing import List, Tuple
from itertools import combinations
from abc import ABC, abstractmethod, abstractstaticmethod, abstractclassmethod
import pandas as pd
import logging

logging.basicConfig()
logger = logging.getLogger("apriori")

# %%
class FileReader(ABC):
    def __init__(self, file_path):
        self.file_path = file_path
        
    @abstractmethod
    def read(self) -> list:
        pass
        
        
class CollapsedCsvFileReader(FileReader):
    """the file format is lines, with individual transactinos"""
    """separated by commma - thus calling this collapsed"""
    """file format as it is non-traditional"""
    def read(self) -> list:
        file_iter = open(self.file_path, 'r')
        raw_transactions = list()
        for line in file_iter:
            line = line.strip().rstrip(',')
            record = tuple(sorted(line.split(',')))
            raw_transactions.append(record)

        return raw_transactions

# %%
class Apriori(object):
# following https://en.wikipedia.org/wiki/Apriori_algorithm#Examples
    def __init__(self, transactions: List):
        self.__verify__(transactions)

        self._transactions = transactions

    def __str__(self):
        return str(tuple(self))


    def __verify__(self, transactions):
        if transactions is None:
            raise ValueError("Transaction itemset is none")

        if not isinstance(transactions, List):
            raise ValueError("Transaction itemset is not a List")

        if len(transactions) == 0:
            raise ValueError("Transaction is empty")

        if len(transactions) > 0 and not isinstance(transactions[0], Tuple):
            raise ValueError("Transaction lement is not a Tuple")


    @property
    def transactions(self):
        return self._itemset_transactions
    

    @transactions.setter
    def transactions(self, value):

        self.__verify__(value)
        self._itemset_transactions = value
        
        
    def generate_levels(self, support_level=0.20, drop_below_support=True):
        k = 1
        # TODO make this a data frame containing other data frames?
        # TODO merge all the levels for final output.
        full_set = list() # this contains a dataframe for each level.
        while True:
            logger.info("k = {0}".format(k))
            item_levels = self.__generate_combinination_levels(self._transactions, k)
            sl = self.__gen_support_level(self._transactions, item_levels, support = support_level, drop = drop_below_support)
            logger.debug("transactions at level {k} are {n}".format(k = k, n = (len(sl))))
            k += 1

            if len(sl) == 0 or k == 100:
                break

            df = pd.DataFrame.from_dict(sl, orient='index', columns=['count'])
            full_set.append(df)
            
        return full_set
    
        
    def __generate_combinination_levels(self, tran_list, level):
        """generate keys that are used for subset checking"""
        """on each transaction"""
        results = list()
        for t in tran_list:
            #logger.debug(t)
            # TODO: figure out why at level 1 trailing comma
            [ (logger.debug("new key: {0}".format(i)), results.append(i)) for i in combinations(t, level)]

        return sorted(set(results))


    def __gen_support_level(self, tran_list, items_keys, support = 0.20, drop = True):
        """for each key which can be a set find in transactions"""
        """how many contain the combination"""        
        logger.info('Using support level of {0}'.format(support))
        logger.info('drop below support? {0}'.format(drop))
        tran_count = len(tran_list)
        base_level = tran_count * support
        logger.info('base level count: {0}'.format(base_level))
        itemSet = dict()

        for key in items_keys:
            for t in tran_list:
                if set(key).issubset(t):
                    logger.debug('is subset: {0}'.format(t))
                    if (key) in itemSet:
                        itemSet[key] += 1
                    else:
                        itemSet[key] = 1

        if drop:
            return {key:value for (key,value) in itemSet.items() if value > base_level}
        else:
            return {key:value for (key,value) in itemSet.items()}

# %%
logging.basicConfig()
logger = logging.getLogger('apriori')
logger.setLevel(logging.INFO)

fr = CollapsedCsvFileReader('./data/test4.csv')
t2 = fr.read()
g = Apriori(t2)
output = g.generate_levels(support_level=0.20)
[(p) for p in output]
# Out:
# INFO:apriori:k = 1
# INFO:apriori:Using support level of 0.2
# INFO:apriori:drop below support? True
# INFO:apriori:base level count: 1.0
# INFO:apriori:k = 2
# INFO:apriori:Using support level of 0.2
# INFO:apriori:drop below support? True
# INFO:apriori:base level count: 1.0
# INFO:apriori:k = 3
# INFO:apriori:Using support level of 0.2
# INFO:apriori:drop below support? True
# INFO:apriori:base level count: 1.0
# INFO:apriori:k = 4
# INFO:apriori:Using support level of 0.2
# INFO:apriori:drop below support? True
# INFO:apriori:base level count: 1.0
# INFO:apriori:k = 5
# INFO:apriori:Using support level of 0.2
# INFO:apriori:drop below support? True
# INFO:apriori:base level count: 1.0
# INFO:apriori:k = 6
# INFO:apriori:Using support level of 0.2
# INFO:apriori:drop below support? True
# INFO:apriori:base level count: 1.0
# [                count
#  (Corn,)             2
#  (Eggs,)             4
#  (KidneyBeans,)      5
#  (Milk,)             3
#  (Nutmeg,)           2
#  (Onion,)            3
#  (Yogurt,)           3,
#                         count
#  (Corn, KidneyBeans)        2
#  (Eggs, KidneyBeans)        4
#  (Eggs, Milk)               2
#  (Eggs, Nutmeg)             2
#  (Eggs, Onion)              3
#  (Eggs, Yogurt)             2
#  (KidneyBeans, Milk)        3
#  (KidneyBeans, Nutmeg)      2
#  (KidneyBeans, Onion)       3
#  (KidneyBeans, Yogurt)      3
#  (Milk, Yogurt)             2
#  (Nutmeg, Onion)            2
#  (Nutmeg, Yogurt)           2
#  (Onion, Yogurt)            2,
#                                 count
#  (Eggs, KidneyBeans, Milk)          2
#  (Eggs, KidneyBeans, Nutmeg)        2
#  (Eggs, KidneyBeans, Onion)         3
#  (Eggs, KidneyBeans, Yogurt)        2
#  (Eggs, Nutmeg, Onion)              2
#  (Eggs, Nutmeg, Yogurt)             2
#  (Eggs, Onion, Yogurt)              2
#  (KidneyBeans, Milk, Yogurt)        2
#  (KidneyBeans, Nutmeg, Onion)       2
#  (KidneyBeans, Nutmeg, Yogurt)      2
#  (KidneyBeans, Onion, Yogurt)       2
#  (Nutmeg, Onion, Yogurt)            2,
#                                        count
#  (Eggs, KidneyBeans, Nutmeg, Onion)        2
#  (Eggs, KidneyBeans, Nutmeg, Yogurt)       2
#  (Eggs, KidneyBeans, Onion, Yogurt)        2
#  (Eggs, Nutmeg, Onion, Yogurt)             2
#  (KidneyBeans, Nutmeg, Onion, Yogurt)      2,
#                                              count
#  (Eggs, KidneyBeans, Nutmeg, Onion, Yogurt)      2]

# %%
print(type(output))

big_df = pd.DataFrame(output)

#[ (print(type(p)), print(p)) for p in output  ]

[ d for d in big_df[0]  ]
# Out:
# <class 'list'>
# [                count
#  (Apple,)            1
#  (Corn,)             2
#  (Dill,)             1
#  (Eggs,)             4
#  (Icecream,)         1
#  (KidneyBeans,)      5
#  (Milk,)             3
#  (Nutmeg,)           2
#  (Onion,)            3
#  (Unicorn,)          1
#  (Yogurt,)           3,
#                           count
#  (Apple, Eggs)                1
#  (Apple, KidneyBeans)         1
#  (Apple, Milk)                1
#  (Corn, Eggs)                 1
#  (Corn, Icecream)             1
#  (Corn, KidneyBeans)          2
#  (Corn, Milk)                 1
#  (Corn, Onion)                1
#  (Corn, Unicorn)              1
#  (Corn, Yogurt)               1
#  (Dill, Eggs)                 1
#  (Dill, KidneyBeans)          1
#  (Dill, Nutmeg)               1
#  (Dill, Onion)                1
#  (Dill, Yogurt)               1
#  (Eggs, Icecream)             1
#  (Eggs, KidneyBeans)          4
#  (Eggs, Milk)                 2
#  (Eggs, Nutmeg)               2
#  (Eggs, Onion)                3
#  (Eggs, Yogurt)               2
#  (Icecream, KidneyBeans)      1
#  (Icecream, Onion)            1
#  (KidneyBeans, Milk)          3
#  (KidneyBeans, Nutmeg)        2
#  (KidneyBeans, Onion)         3
#  (KidneyBeans, Unicorn)       1
#  (KidneyBeans, Yogurt)        3
#  (Milk, Nutmeg)               1
#  (Milk, Onion)                1
#  (Milk, Unicorn)              1
#  (Milk, Yogurt)               2
#  (Nutmeg, Onion)              2
#  (Nutmeg, Yogurt)             2
#  (Onion, Yogurt)              2
#  (Unicorn, Yogurt)            1,
#                                  count
#  (Apple, Eggs, KidneyBeans)          1
#  (Apple, Eggs, Milk)                 1
#  (Apple, KidneyBeans, Milk)          1
#  (Corn, Eggs, Icecream)              1
#  (Corn, Eggs, KidneyBeans)           1
#  (Corn, Eggs, Onion)                 1
#  (Corn, Icecream, KidneyBeans)       1
#  (Corn, Icecream, Onion)             1
#  (Corn, KidneyBeans, Milk)           1
#  (Corn, KidneyBeans, Onion)          1
#  (Corn, KidneyBeans, Unicorn)        1
#  (Corn, KidneyBeans, Yogurt)         1
#  (Corn, Milk, Unicorn)               1
#  (Corn, Milk, Yogurt)                1
#  (Corn, Unicorn, Yogurt)             1
#  (Dill, Eggs, KidneyBeans)           1
#  (Dill, Eggs, Nutmeg)                1
#  (Dill, Eggs, Onion)                 1
#  (Dill, Eggs, Yogurt)                1
#  (Dill, KidneyBeans, Nutmeg)         1
#  (Dill, KidneyBeans, Onion)          1
#  (Dill, KidneyBeans, Yogurt)         1
#  (Dill, Nutmeg, Onion)               1
#  (Dill, Nutmeg, Yogurt)              1
#  (Dill, Onion, Yogurt)               1
#  (Eggs, Icecream, KidneyBeans)       1
#  (Eggs, Icecream, Onion)             1
#  (Eggs, KidneyBeans, Milk)           2
#  (Eggs, KidneyBeans, Nutmeg)         2
#  (Eggs, KidneyBeans, Onion)          3
#  (Eggs, KidneyBeans, Yogurt)         2
#  (Eggs, Milk, Nutmeg)                1
#  (Eggs, Milk, Onion)                 1
#  (Eggs, Milk, Yogurt)                1
#  (Eggs, Nutmeg, Onion)               2
#  (Eggs, Nutmeg, Yogurt)              2
#  (Eggs, Onion, Yogurt)               2
#  (Icecream, KidneyBeans, Onion)      1
#  (KidneyBeans, Milk, Nutmeg)         1
#  (KidneyBeans, Milk, Onion)          1
#  (KidneyBeans, Milk, Unicorn)        1
#  (KidneyBeans, Milk, Yogurt)         2
#  (KidneyBeans, Nutmeg, Onion)        2
#  (KidneyBeans, Nutmeg, Yogurt)       2
#  (KidneyBeans, Onion, Yogurt)        2
#  (KidneyBeans, Unicorn, Yogurt)      1
#  (Milk, Nutmeg, Onion)               1
#  (Milk, Nutmeg, Yogurt)              1
#  (Milk, Onion, Yogurt)               1
#  (Milk, Unicorn, Yogurt)             1
#  (Nutmeg, Onion, Yogurt)             2,
#                                        count
#  (Apple, Eggs, KidneyBeans, Milk)          1
#  (Corn, Eggs, Icecream, KidneyBeans)       1
#  (Corn, Eggs, Icecream, Onion)             1
#  (Corn, Eggs, KidneyBeans, Onion)          1
#  (Corn, Icecream, KidneyBeans, Onion)      1
#  (Corn, KidneyBeans, Milk, Unicorn)        1
#  (Corn, KidneyBeans, Milk, Yogurt)         1
#  (Corn, KidneyBeans, Unicorn, Yogurt)      1
#  (Corn, Milk, Unicorn, Yogurt)             1
#  (Dill, Eggs, KidneyBeans, Nutmeg)         1
#  (Dill, Eggs, KidneyBeans, Onion)          1
#  (Dill, Eggs, KidneyBeans, Yogurt)         1
#  (Dill, Eggs, Nutmeg, Onion)               1
#  (Dill, Eggs, Nutmeg, Yogurt)              1
#  (Dill, Eggs, Onion, Yogurt)               1
#  (Dill, KidneyBeans, Nutmeg, Onion)        1
#  (Dill, KidneyBeans, Nutmeg, Yogurt)       1
#  (Dill, KidneyBeans, Onion, Yogurt)        1
#  (Dill, Nutmeg, Onion, Yogurt)             1
#  (Eggs, Icecream, KidneyBeans, Onion)      1
#  (Eggs, KidneyBeans, Milk, Nutmeg)         1
#  (Eggs, KidneyBeans, Milk, Onion)          1
#  (Eggs, KidneyBeans, Milk, Yogurt)         1
#  (Eggs, KidneyBeans, Nutmeg, Onion)        2
#  (Eggs, KidneyBeans, Nutmeg, Yogurt)       2
#  (Eggs, KidneyBeans, Onion, Yogurt)        2
#  (Eggs, Milk, Nutmeg, Onion)               1
#  (Eggs, Milk, Nutmeg, Yogurt)              1
#  (Eggs, Milk, Onion, Yogurt)               1
#  (Eggs, Nutmeg, Onion, Yogurt)             2
#  (KidneyBeans, Milk, Nutmeg, Onion)        1
#  (KidneyBeans, Milk, Nutmeg, Yogurt)       1
#  (KidneyBeans, Milk, Onion, Yogurt)        1
#  (KidneyBeans, Milk, Unicorn, Yogurt)      1
#  (KidneyBeans, Nutmeg, Onion, Yogurt)      2
#  (Milk, Nutmeg, Onion, Yogurt)             1,
#                                              count
#  (Corn, Eggs, Icecream, KidneyBeans, Onion)      1
#  (Corn, KidneyBeans, Milk, Unicorn, Yogurt)      1
#  (Dill, Eggs, KidneyBeans, Nutmeg, Onion)        1
#  (Dill, Eggs, KidneyBeans, Nutmeg, Yogurt)       1
#  (Dill, Eggs, KidneyBeans, Onion, Yogurt)        1
#  (Dill, Eggs, Nutmeg, Onion, Yogurt)             1
#  (Dill, KidneyBeans, Nutmeg, Onion, Yogurt)      1
#  (Eggs, KidneyBeans, Milk, Nutmeg, Onion)        1
#  (Eggs, KidneyBeans, Milk, Nutmeg, Yogurt)       1
#  (Eggs, KidneyBeans, Milk, Onion, Yogurt)        1
#  (Eggs, KidneyBeans, Nutmeg, Onion, Yogurt)      2
#  (Eggs, Milk, Nutmeg, Onion, Yogurt)             1
#  (KidneyBeans, Milk, Nutmeg, Onion, Yogurt)      1,
#                                                    count
#  (Dill, Eggs, KidneyBeans, Nutmeg, Onion, Yogurt)      1
#  (Eggs, KidneyBeans, Milk, Nutmeg, Onion, Yogurt)      1]
