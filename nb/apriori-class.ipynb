# %%
from typing import List, Tuple
from itertools import combinations
from abc import ABC, abstractmethod, abstractstaticmethod, abstractclassmethod
import pandas as pd
import logging

logging.basicConfig()
logger = logging.getLogger("apriori")

# %%
class FileReader(ABC):
    def __init__(self, file_path):
        self.file_path = file_path
        
    @abstractmethod
    def read(self) -> list:
        pass
        
        
class CollapsedCsvFileReader(FileReader):
    """the file format is lines, with individual transactinos"""
    """separated by commma - thus calling this collapsed"""
    """file format as it is non-traditional"""
    def read(self) -> list:
        file_iter = open(self.file_path, 'r')
        raw_transactions = list()
        for line in file_iter:
            line = line.strip().rstrip(',')
            record = tuple(sorted(line.split(',')))
            raw_transactions.append(record)

        return raw_transactions

# %%
class Apriori(object):
# following https://en.wikipedia.org/wiki/Apriori_algorithm#Examples
    def __init__(self, transactions: List):
        self.__verify__(transactions)

        self._transactions = transactions

    def __str__(self):
        return str(tuple(self))


    def __verify__(self, transactions):
        if transactions is None:
            raise ValueError("Transaction itemset is none")

        if not isinstance(transactions, List):
            raise ValueError("Transaction itemset is not a List")

        if len(transactions) == 0:
            raise ValueError("Transaction is empty")

        if len(transactions) > 0 and not isinstance(transactions[0], Tuple):
            raise ValueError("Transaction lement is not a Tuple")


    @property
    def transactions(self) -> List:
        return self._transactions
    

    @transactions.setter
    def transactions(self, value: List):

        self.__verify__(value)
        self._transactions  = value
        
        
    def generate_levels(self, support_level=0.20, drop_below_support=True) -> pd.DataFrame:
        k = 1
        full_set = list() # this contains a dataframe for each level.
        while True:
            logger.info("k = {0}".format(k))
            item_levels = self.__generate_combinination_levels(self._transactions, k)
            sl = self.__gen_support_level(self._transactions, item_levels, 
                                          support = support_level, drop = drop_below_support)
            
            #logger.debug("transactions at level {k} are {n}".format(k = k, n = (len(sl))))
            k += 1

            if len(sl) == 0 or k == 100:
                break

            df = pd.DataFrame.from_dict(sl, orient='index', columns=['count'])
            df.index.name = 'itemset'
            df.reset_index()
            full_set.append(df)
            
        rv = self.__append_colums(full_set)
        return rv
    
    def __append_colums(self, data: List, tran_list = None) -> pd.DataFrame:
        if tran_list == None:
            tran_list = self.transactions
            
        tran_count = len(tran_list)
        
        rows_list = []
        for r in data:
            #logger.debug('type of r is: {0}'.format(type(r)))
            #logger.debug('len of r is: {0}'.format(len(r)))
            #logger.debug('r is: {0}'.format(r))
            for index, row in r.iterrows():
                #d = { 'count' : r['count'], 'support': r['count']/tran_count}
                d = {'itemset': index, 'count' : row['count'], 'support': row['count']/tran_count}
                #logger.debug("THE DICTd: {0}".format(d))
                rows_list.append(d)
            
        # TODO: fix rv
        
        df = pd.DataFrame(rows_list)
        
        #logger.debug(df)
        return df  #data
        
        
    def __generate_combinination_levels(self, tran_list, level):
        """generate keys that are used for subset checking"""
        """on each transaction"""
        results = list()
        for t in tran_list:
            logger.debug("gen_com_levell: t: {0}  and level: {1}".format(t, level))
            # TODO: figure out why at level 1 trailing comma
            #if level == 1:
            #    results.append(t)
            #else:
            [ results.append(i) for i in combinations(t, level)]


        rv = sorted(set(results))
        logger.debug("combo levels: {0}".format(rv))
        return rv


    def __gen_support_level(self, tran_list, items_keys, support = 0.20, drop = True):
        """for each key which can be a set find in transactions"""
        """how many contain the combination"""        
        logger.info('Using support level of {0}'.format(support))
        logger.info('drop below support? {0}'.format(drop))
        tran_count = len(tran_list)
        base_level = tran_count * support
        logger.debug('base level count: {0}'.format(base_level))
        itemSet = dict()

        for key in items_keys:
            for t in tran_list:
                if set(key).issubset(t):
                    #logger.debug('is subset: {0}'.format(t))
                    if (key) in itemSet:
                        itemSet[key] += 1
                    else:
                        itemSet[key] = 1

        if drop:
            return {key:value for (key,value) in itemSet.items() if value >= base_level}
        else:
            return {key:value for (key,value) in itemSet.items()}

# %%
logging.basicConfig()
logger = logging.getLogger('apriori')
logger.setLevel(logging.DEBUG)

fr = CollapsedCsvFileReader('./data/test4.csv')
t2 = fr.read()

#logger.info("tran count: {0}".format(t2))
g = Apriori(t2)
output = g.generate_levels(support_level=0.60, drop_below_support=True)


#out2 = g.append_colums(output)



#[(p) for p in out2]
# Out:
# INFO:apriori:k = 1
# DEBUG:apriori:gen_com_levell: t: ('Eggs', 'KidneyBeans', 'Milk', 'Nutmeg', 'Onion', 'Yogurt')  and level: 1
# DEBUG:apriori:gen_com_levell: t: ('Dill', 'Eggs', 'KidneyBeans', 'Nutmeg', 'Onion', 'Yogurt')  and level: 1
# DEBUG:apriori:gen_com_levell: t: ('Apple', 'Eggs', 'KidneyBeans', 'Milk')  and level: 1
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'KidneyBeans', 'Milk', 'Unicorn', 'Yogurt')  and level: 1
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'Eggs', 'Icecream', 'KidneyBeans', 'Onion')  and level: 1
# DEBUG:apriori:combo levels: [('Apple',), ('Corn',), ('Dill',), ('Eggs',), ('Icecream',), ('KidneyBeans',), ('Milk',), ('Nutmeg',), ('Onion',), ('Unicorn',), ('Yogurt',)]
# INFO:apriori:Using support level of 0.6
# INFO:apriori:drop below support? True
# DEBUG:apriori:base level count: 3.0
# INFO:apriori:k = 2
# DEBUG:apriori:gen_com_levell: t: ('Eggs', 'KidneyBeans', 'Milk', 'Nutmeg', 'Onion', 'Yogurt')  and level: 2
# DEBUG:apriori:gen_com_levell: t: ('Dill', 'Eggs', 'KidneyBeans', 'Nutmeg', 'Onion', 'Yogurt')  and level: 2
# DEBUG:apriori:gen_com_levell: t: ('Apple', 'Eggs', 'KidneyBeans', 'Milk')  and level: 2
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'KidneyBeans', 'Milk', 'Unicorn', 'Yogurt')  and level: 2
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'Eggs', 'Icecream', 'KidneyBeans', 'Onion')  and level: 2
# DEBUG:apriori:combo levels: [('Apple', 'Eggs'), ('Apple', 'KidneyBeans'), ('Apple', 'Milk'), ('Corn', 'Eggs'), ('Corn', 'Icecream'), ('Corn', 'KidneyBeans'), ('Corn', 'Milk'), ('Corn', 'Onion'), ('Corn', 'Unicorn'), ('Corn', 'Yogurt'), ('Dill', 'Eggs'), ('Dill', 'KidneyBeans'), ('Dill', 'Nutmeg'), ('Dill', 'Onion'), ('Dill', 'Yogurt'), ('Eggs', 'Icecream'), ('Eggs', 'KidneyBeans'), ('Eggs', 'Milk'), ('Eggs', 'Nutmeg'), ('Eggs', 'Onion'), ('Eggs', 'Yogurt'), ('Icecream', 'KidneyBeans'), ('Icecream', 'Onion'), ('KidneyBeans', 'Milk'), ('KidneyBeans', 'Nutmeg'), ('KidneyBeans', 'Onion'), ('KidneyBeans', 'Unicorn'), ('KidneyBeans', 'Yogurt'), ('Milk', 'Nutmeg'), ('Milk', 'Onion'), ('Milk', 'Unicorn'), ('Milk', 'Yogurt'), ('Nutmeg', 'Onion'), ('Nutmeg', 'Yogurt'), ('Onion', 'Yogurt'), ('Unicorn', 'Yogurt')]
# INFO:apriori:Using support level of 0.6
# INFO:apriori:drop below support? True
# DEBUG:apriori:base level count: 3.0
# INFO:apriori:k = 3
# DEBUG:apriori:gen_com_levell: t: ('Eggs', 'KidneyBeans', 'Milk', 'Nutmeg', 'Onion', 'Yogurt')  and level: 3
# DEBUG:apriori:gen_com_levell: t: ('Dill', 'Eggs', 'KidneyBeans', 'Nutmeg', 'Onion', 'Yogurt')  and level: 3
# DEBUG:apriori:gen_com_levell: t: ('Apple', 'Eggs', 'KidneyBeans', 'Milk')  and level: 3
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'KidneyBeans', 'Milk', 'Unicorn', 'Yogurt')  and level: 3
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'Eggs', 'Icecream', 'KidneyBeans', 'Onion')  and level: 3
# DEBUG:apriori:combo levels: [('Apple', 'Eggs', 'KidneyBeans'), ('Apple', 'Eggs', 'Milk'), ('Apple', 'KidneyBeans', 'Milk'), ('Corn', 'Eggs', 'Icecream'), ('Corn', 'Eggs', 'KidneyBeans'), ('Corn', 'Eggs', 'Onion'), ('Corn', 'Icecream', 'KidneyBeans'), ('Corn', 'Icecream', 'Onion'), ('Corn', 'KidneyBeans', 'Milk'), ('Corn', 'KidneyBeans', 'Onion'), ('Corn', 'KidneyBeans', 'Unicorn'), ('Corn', 'KidneyBeans', 'Yogurt'), ('Corn', 'Milk', 'Unicorn'), ('Corn', 'Milk', 'Yogurt'), ('Corn', 'Unicorn', 'Yogurt'), ('Dill', 'Eggs', 'KidneyBeans'), ('Dill', 'Eggs', 'Nutmeg'), ('Dill', 'Eggs', 'Onion'), ('Dill', 'Eggs', 'Yogurt'), ('Dill', 'KidneyBeans', 'Nutmeg'), ('Dill', 'KidneyBeans', 'Onion'), ('Dill', 'KidneyBeans', 'Yogurt'), ('Dill', 'Nutmeg', 'Onion'), ('Dill', 'Nutmeg', 'Yogurt'), ('Dill', 'Onion', 'Yogurt'), ('Eggs', 'Icecream', 'KidneyBeans'), ('Eggs', 'Icecream', 'Onion'), ('Eggs', 'KidneyBeans', 'Milk'), ('Eggs', 'KidneyBeans', 'Nutmeg'), ('Eggs', 'KidneyBeans', 'Onion'), ('Eggs', 'KidneyBeans', 'Yogurt'), ('Eggs', 'Milk', 'Nutmeg'), ('Eggs', 'Milk', 'Onion'), ('Eggs', 'Milk', 'Yogurt'), ('Eggs', 'Nutmeg', 'Onion'), ('Eggs', 'Nutmeg', 'Yogurt'), ('Eggs', 'Onion', 'Yogurt'), ('Icecream', 'KidneyBeans', 'Onion'), ('KidneyBeans', 'Milk', 'Nutmeg'), ('KidneyBeans', 'Milk', 'Onion'), ('KidneyBeans', 'Milk', 'Unicorn'), ('KidneyBeans', 'Milk', 'Yogurt'), ('KidneyBeans', 'Nutmeg', 'Onion'), ('KidneyBeans', 'Nutmeg', 'Yogurt'), ('KidneyBeans', 'Onion', 'Yogurt'), ('KidneyBeans', 'Unicorn', 'Yogurt'), ('Milk', 'Nutmeg', 'Onion'), ('Milk', 'Nutmeg', 'Yogurt'), ('Milk', 'Onion', 'Yogurt'), ('Milk', 'Unicorn', 'Yogurt'), ('Nutmeg', 'Onion', 'Yogurt')]
# INFO:apriori:Using support level of 0.6
# INFO:apriori:drop below support? True
# DEBUG:apriori:base level count: 3.0
# INFO:apriori:k = 4
# DEBUG:apriori:gen_com_levell: t: ('Eggs', 'KidneyBeans', 'Milk', 'Nutmeg', 'Onion', 'Yogurt')  and level: 4
# DEBUG:apriori:gen_com_levell: t: ('Dill', 'Eggs', 'KidneyBeans', 'Nutmeg', 'Onion', 'Yogurt')  and level: 4
# DEBUG:apriori:gen_com_levell: t: ('Apple', 'Eggs', 'KidneyBeans', 'Milk')  and level: 4
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'KidneyBeans', 'Milk', 'Unicorn', 'Yogurt')  and level: 4
# DEBUG:apriori:gen_com_levell: t: ('Corn', 'Eggs', 'Icecream', 'KidneyBeans', 'Onion')  and level: 4
# DEBUG:apriori:combo levels: [('Apple', 'Eggs', 'KidneyBeans', 'Milk'), ('Corn', 'Eggs', 'Icecream', 'KidneyBeans'), ('Corn', 'Eggs', 'Icecream', 'Onion'), ('Corn', 'Eggs', 'KidneyBeans', 'Onion'), ('Corn', 'Icecream', 'KidneyBeans', 'Onion'), ('Corn', 'KidneyBeans', 'Milk', 'Unicorn'), ('Corn', 'KidneyBeans', 'Milk', 'Yogurt'), ('Corn', 'KidneyBeans', 'Unicorn', 'Yogurt'), ('Corn', 'Milk', 'Unicorn', 'Yogurt'), ('Dill', 'Eggs', 'KidneyBeans', 'Nutmeg'), ('Dill', 'Eggs', 'KidneyBeans', 'Onion'), ('Dill', 'Eggs', 'KidneyBeans', 'Yogurt'), ('Dill', 'Eggs', 'Nutmeg', 'Onion'), ('Dill', 'Eggs', 'Nutmeg', 'Yogurt'), ('Dill', 'Eggs', 'Onion', 'Yogurt'), ('Dill', 'KidneyBeans', 'Nutmeg', 'Onion'), ('Dill', 'KidneyBeans', 'Nutmeg', 'Yogurt'), ('Dill', 'KidneyBeans', 'Onion', 'Yogurt'), ('Dill', 'Nutmeg', 'Onion', 'Yogurt'), ('Eggs', 'Icecream', 'KidneyBeans', 'Onion'), ('Eggs', 'KidneyBeans', 'Milk', 'Nutmeg'), ('Eggs', 'KidneyBeans', 'Milk', 'Onion'), ('Eggs', 'KidneyBeans', 'Milk', 'Yogurt'), ('Eggs', 'KidneyBeans', 'Nutmeg', 'Onion'), ('Eggs', 'KidneyBeans', 'Nutmeg', 'Yogurt'), ('Eggs', 'KidneyBeans', 'Onion', 'Yogurt'), ('Eggs', 'Milk', 'Nutmeg', 'Onion'), ('Eggs', 'Milk', 'Nutmeg', 'Yogurt'), ('Eggs', 'Milk', 'Onion', 'Yogurt'), ('Eggs', 'Nutmeg', 'Onion', 'Yogurt'), ('KidneyBeans', 'Milk', 'Nutmeg', 'Onion'), ('KidneyBeans', 'Milk', 'Nutmeg', 'Yogurt'), ('KidneyBeans', 'Milk', 'Onion', 'Yogurt'), ('KidneyBeans', 'Milk', 'Unicorn', 'Yogurt'), ('KidneyBeans', 'Nutmeg', 'Onion', 'Yogurt'), ('Milk', 'Nutmeg', 'Onion', 'Yogurt')]
# INFO:apriori:Using support level of 0.6
# INFO:apriori:drop below support? True
# DEBUG:apriori:base level count: 3.0

# %%
t2
# Out:
# [('Eggs', 'KidneyBeans', 'Milk', 'Nutmeg', 'Onion', 'Yogurt'),
#  ('Dill', 'Eggs', 'KidneyBeans', 'Nutmeg', 'Onion', 'Yogurt'),
#  ('Apple', 'Eggs', 'KidneyBeans', 'Milk'),
#  ('Corn', 'KidneyBeans', 'Milk', 'Unicorn', 'Yogurt'),
#  ('Corn', 'Eggs', 'Icecream', 'KidneyBeans', 'Onion')]

# %%
output
# Out:
#                        itemset  count  support
# 0                      (Eggs,)      4      0.8
# 1               (KidneyBeans,)      5      1.0
# 2                      (Milk,)      3      0.6
# 3                     (Onion,)      3      0.6
# 4                    (Yogurt,)      3      0.6
# 5          (Eggs, KidneyBeans)      4      0.8
# 6                (Eggs, Onion)      3      0.6
# 7          (KidneyBeans, Milk)      3      0.6
# 8         (KidneyBeans, Onion)      3      0.6
# 9        (KidneyBeans, Yogurt)      3      0.6
# 10  (Eggs, KidneyBeans, Onion)      3      0.6

# %%
logger.setLevel(logging.DEBUG)
#out2 = g.append_colums(output)

[(p) for p in output]

# %%
print(type(output))

big_df = pd.DataFrame(output)

#[ (print(type(p)), print(p)) for p in output  ]

[ d for d in big_df[0]  ]
